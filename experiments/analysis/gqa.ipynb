# %%
import json
import yaml
import os
import numpy as np
import pandas as pd
from collections import defaultdict
import matplotlib
import matplotlib.pyplot as plt
from IPython.display import display, HTML
config = yaml.safe_load(open("/gscratch/balazinska/enhaoz/VOCAL-UDF/configs/config.yaml", "r"))

import re
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

CB_color_cycle = ['#377eb8', '#ff7f00', '#4daf4a',
                  '#f781bf', '#a65628', '#984ea3',
                  '#999999', '#e41a1c', '#dede00']

# %%
# Define LLM models, tasks, number of new UDFs, and hatch patterns
llm_models = ['gpt-4-1106-preview', 'equi-vocal', 'unavailable_removed', 'vocal-udf']
llm_model_labels = ['visprog', 'equi-vocal', 'unavailable_removed', 'vocal-udf']
query_class_names = [
    # "unavailable=2-npred=1-nattr_pred=1-nobj_pred=0-nvars=2-min_npos=100-max_npos=5000",
    "unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000"
    ]
tasks = [f"{i}_new_udfs" for i in range(1, 3)]
easy_question_ids = [0, 2, 4, 5, 7]
hard_question_ids = [1, 3, 6, 8, 9]
question_ids = sorted(easy_question_ids + hard_question_ids)
num_new_udfs = [1, 2]
# num_new_udfs = [0, 1]
hatch_patterns = ['...', '///', '\\\\\\', 'xxx', '***', '+++', '|||', '---', 'ooo']
handles_f1 = []

# Create a figure and axis for the boxplot
fig, ax = plt.subplots(1, 1, figsize=(3, 2.7))  # Adjust the figsize as needed

# Iterate through LLM models
for i, llm_model in enumerate(llm_models):
    print(f"######## {llm_model} ########")
    f1_data = []

    # Iterate through tasks
    for task_id in range(1, 3):
        task = f"{task_id}_new_udfs"
        accuracy_list = []
        f1_list = []
        precision_list = []
        recall_list = []
        failed_list = []

        # Iterate through runs and questions
        if llm_model in ["unavailable_removed"]:
            if task_id != 0:
                for query_class_name in query_class_names:
                    for question_id in question_ids:
                        try:
                            with open(os.path.join(config['log_dir'], "query_execution", "gqa", query_class_name, f"num_missing_udfs={task_id}", "queries_unavailable_udfs_removed", f"qid={question_id}.log"), "r") as f:
                                last_line = f.readlines()[-1]
                            f1_score_pattern = r"F1 score: ([0-9.]+)"
                            match = re.search(f1_score_pattern, last_line)
                            f1_score = float(match.group(1))
                            f1_list.append(f1_score)
                        except Exception as e:
                            print(e)
                            continue

        elif llm_model in ["equi-vocal"]:
            if task_id != 0:
                for query_class_name in query_class_names:
                    for run_id in range(1):
                        for question_id in question_ids:
                            try:
                                with open(os.path.join(config['log_dir'], "query_execution", "gqa", query_class_name, f"num_missing_udfs={task_id}", llm_model, f"qid={question_id}-run={run_id}.log"), "r") as f:
                                    last_line = f.readlines()[-1]
                                f1_score_pattern = r"F1 score: ([0-9.]+)"
                                match = re.search(f1_score_pattern, last_line)
                                f1_score = float(match.group(1))
                                f1_list.append(f1_score)
                            except Exception as e:
                                print(e)
                                continue

        elif llm_model in ['vocal-udf']:
            if task_id != 0:
                for query_class_name in query_class_names:
                    for run_id in range(1):
                        for question_id in question_ids:
                            try:
                                with open(os.path.join(config['log_dir'], "query_execution", "gqa", query_class_name, f"num_missing_udfs={task_id}", "ninterp=10-nparams=5-kwargs=True-pixels=True-pretrained_models=False-ntrain_distill=100-selection=both-labels=user-budget=50-llm_method=gpt4v", f"qid={question_id}-run={run_id}.log"), "r") as f:
                                    target_line = f.readlines()[-2]
                                f1_score_pattern = r"F1 score: ([0-9.]+)"
                                match = re.search(f1_score_pattern, target_line)
                                f1_score = 0
                                if match:
                                    f1_score = float(match.group(1))
                                    failed_list.append(0)
                                else:
                                    print(f"failed task: qid={question_id}-run={run_id}")
                                    failed_list.append(1)
                                f1_list.append(f1_score)
                                accuracy_list.append(-1)
                                precision_list.append(-1)
                                recall_list.append(-1)
                            except Exception as e:
                                print(e)
                                continue
        else:
            for run_id in range(5):
                for question_id in question_ids:
                    try:
                        with open(os.path.join(config['output_dir'], "gqa", llm_model, f"task_{task}_labels_run_{run_id}_question_{question_id}.json"), "r") as f:
                            data = json.load(f)
                        accuracy_list.append(data["accuracy"])
                        f1_list.append(data["f1"])
                        precision_list.append(data["precision"])
                        recall_list.append(data["recall"])
                        failed_list.append(data["failed"])
                        if '0' in task and data["failed"] > 0:
                            print(run_id, question_id)
                    except Exception as e:
                        print(e)
                        continue


        f1_data.append(f1_list)
        print(f"task_{task}_mean_accuracy: {np.mean(accuracy_list)}")
        print(f"task_{task}_mean_f1: {np.mean(f1_list)}")
        print(f"task_{task}_mean_precision: {np.mean(precision_list)}")
        print(f"task_{task}_mean_recall: {np.mean(recall_list)}")
        print(f"task_{task}_prob_failures: {np.mean(failed_list)}")
        print()

    # Create a grouped boxplot for F1 scores
    bp_f1 = ax.boxplot(f1_data,
                       positions=np.array(range(len(f1_data))) * (len(llm_models) + 1) + i,
                       sym='.',
                       widths=1,
                       showfliers=False,
                       patch_artist=True,
                       boxprops=dict(facecolor=CB_color_cycle[i], hatch=hatch_patterns[i]),
                       medianprops=dict(color='black'))
    handles_f1.append(bp_f1["boxes"][0])

# Customize the plot labels and legend
ax.set_title(f"question_ids: {question_ids}")
ax.set(ylabel="F1 Score")
ax.set(xlabel="# new UDFs")
ax.set_ylim(bottom=0, top=1.05)
ax.set_xlim(left=-1.5)
ax.set_xticks(np.arange(len(llm_models) / 2 - 0.5, len(num_new_udfs) * len(llm_models) + len(llm_models) / 2 + 0.5, len(llm_models) + 1))
ax.set_xticklabels(num_new_udfs)
fig.legend(handles_f1, llm_model_labels, prop={"size": 10}, loc='upper center', bbox_to_anchor=(0.5, 0.07),
           fancybox=True, shadow=False, ncol=2)
plt.subplots_adjust(bottom=0.15)
fig.tight_layout()
plt.show()
# Out:
# ######## gpt-4-1106-preview ########
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_9.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_9.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_9.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_9.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_9.json'
# task_1_new_udfs_mean_accuracy: nan
# task_1_new_udfs_mean_f1: nan
# task_1_new_udfs_mean_precision: nan
# task_1_new_udfs_mean_recall: nan
# task_1_new_udfs_prob_failures: nan
#
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_9.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_9.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_9.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_9.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/gqa/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_9.json'
# task_2_new_udfs_mean_accuracy: nan
# task_2_new_udfs_mean_f1: nan
# task_2_new_udfs_mean_precision: nan
# task_2_new_udfs_mean_recall: nan
# task_2_new_udfs_prob_failures: nan
#
# ######## equi-vocal ########
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=1/equi-vocal/qid=0-run=0.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=1/equi-vocal/qid=1-run=0.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=1/equi-vocal/qid=2-run=0.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=1/equi-vocal/qid=3-run=0.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=1/equi-vocal/qid=4-run=0.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=1/equi-vocal/qid=5-run=0.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=1/equi-vocal/qid=6-run=0.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=1/equi-vocal/qid=7-run=0.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=1/equi-vocal/qid=8-run=0.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=1/equi-vocal/qid=9-run=0.log'
# task_1_new_udfs_mean_accuracy: nan
# task_1_new_udfs_mean_f1: nan
# task_1_new_udfs_mean_precision: nan
# task_1_new_udfs_mean_recall: nan
# task_1_new_udfs_prob_failures: nan
#
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/equi-vocal/qid=0-run=0.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/equi-vocal/qid=1-run=0.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/equi-vocal/qid=2-run=0.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/equi-vocal/qid=3-run=0.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/equi-vocal/qid=4-run=0.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/equi-vocal/qid=5-run=0.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/equi-vocal/qid=6-run=0.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/equi-vocal/qid=7-run=0.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/equi-vocal/qid=8-run=0.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/equi-vocal/qid=9-run=0.log'
# task_2_new_udfs_mean_accuracy: nan
# task_2_new_udfs_mean_f1: nan
# task_2_new_udfs_mean_precision: nan
# task_2_new_udfs_mean_recall: nan
# task_2_new_udfs_prob_failures: nan
#
# ######## unavailable_removed ########
# 'NoneType' object has no attribute 'group'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=1/queries_unavailable_udfs_removed/qid=1.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=1/queries_unavailable_udfs_removed/qid=2.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=1/queries_unavailable_udfs_removed/qid=3.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=1/queries_unavailable_udfs_removed/qid=4.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=1/queries_unavailable_udfs_removed/qid=5.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=1/queries_unavailable_udfs_removed/qid=6.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=1/queries_unavailable_udfs_removed/qid=7.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=1/queries_unavailable_udfs_removed/qid=8.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=1/queries_unavailable_udfs_removed/qid=9.log'
# task_1_new_udfs_mean_accuracy: nan
# task_1_new_udfs_mean_f1: nan
# task_1_new_udfs_mean_precision: nan
# task_1_new_udfs_mean_recall: nan
# task_1_new_udfs_prob_failures: nan
#
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/queries_unavailable_udfs_removed/qid=0.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/queries_unavailable_udfs_removed/qid=1.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/queries_unavailable_udfs_removed/qid=2.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/queries_unavailable_udfs_removed/qid=3.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/queries_unavailable_udfs_removed/qid=4.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/queries_unavailable_udfs_removed/qid=5.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/queries_unavailable_udfs_removed/qid=6.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/queries_unavailable_udfs_removed/qid=7.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/queries_unavailable_udfs_removed/qid=8.log'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/logs/query_execution/gqa/unavailable=2-npred=1-nattr_pred=2-nobj_pred=0-nvars=3-min_npos=100-max_npos=5000/num_missing_udfs=2/queries_unavailable_udfs_removed/qid=9.log'
# task_2_new_udfs_mean_accuracy: nan
# task_2_new_udfs_mean_f1: nan
# task_2_new_udfs_mean_precision: nan
# task_2_new_udfs_mean_recall: nan
# task_2_new_udfs_prob_failures: nan
#
# ######## vocal-udf ########
# /gscratch/balazinska/enhaoz/jupyter/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /gscratch/balazinska/enhaoz/jupyter/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /gscratch/balazinska/enhaoz/jupyter/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /gscratch/balazinska/enhaoz/jupyter/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /gscratch/balazinska/enhaoz/jupyter/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /gscratch/balazinska/enhaoz/jupyter/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# failed task: qid=8-run=0
# task_1_new_udfs_mean_accuracy: -1.0
# task_1_new_udfs_mean_f1: 0.08694755335899351
# task_1_new_udfs_mean_precision: -1.0
# task_1_new_udfs_mean_recall: -1.0
# task_1_new_udfs_prob_failures: 0.1
#
# failed task: qid=3-run=0
# task_2_new_udfs_mean_accuracy: -1.0
# task_2_new_udfs_mean_f1: 0.013596124785694294
# task_2_new_udfs_mean_precision: -1.0
# task_2_new_udfs_mean_recall: -1.0
# task_2_new_udfs_prob_failures: 0.1

# %%
# Define LLM models, tasks, number of new UDFs, and hatch patterns
llm_models = ['gpt-4-1106-preview', 'equi-vocal', 'unavailable_removed', 'vocal-udf']
llm_model_labels = ['visprog', 'equi-vocal', 'unavailable_removed', 'vocal-udf']
query_class_names = [
    "unavailable=2-npred=4-nobj_pred=1-nvars=3-depth=2", "unavailable=2-npred=4-nobj_pred=1-nvars=2-depth=2",
    "unavailable=2-npred=3-nobj_pred=1-nvars=2-depth=2"
    ]
tasks = [f"{i}_new_udfs" for i in range(1, 3)]
easy_question_ids = [0, 2, 4, 5, 7]
hard_question_ids = [1, 3, 6, 8, 9]
question_ids = sorted(easy_question_ids + hard_question_ids)
num_new_udfs = [1, 2]
# num_new_udfs = [0, 1]
hatch_patterns = ['...', '///', '\\\\\\', 'xxx', '***', '+++', '|||', '---', 'ooo']
handles_f1 = []

# method_means = defaultdict(list)
# method_stds = defaultdict(list)

x = np.arange(len(tasks))  # the label locations
width = 1 / (len(llm_models) + 1) # the width of the bars
multiplier = 0

# Create a figure and axis for the boxplot
fig, ax = plt.subplots(1, 1, figsize=(3, 2.7))  # Adjust the figsize as needed

# Iterate through LLM models
for i, llm_model in enumerate(llm_models):
    print(f"######## {llm_model} ########")

    mean_list = []
    std_list = []

    # Iterate through tasks
    for task_id in range(1, 3):
        task = f"{task_id}_new_udfs"
        accuracy_list = []
        f1_list = []
        precision_list = []
        recall_list = []
        failed_list = []

        # Iterate through runs and questions
        if llm_model in ["unavailable_removed"]:
            if task_id != 0:
                for query_class_name in query_class_names:
                    for question_id in question_ids:
                        try:
                            with open(os.path.join(config['log_dir'], "query_execution", "charades", query_class_name, f"num_missing_udfs={task_id}", "queries_unavailable_udfs_removed", f"qid={question_id}.log"), "r") as f:
                                last_line = f.readlines()[-1]
                            f1_score_pattern = r"F1 score: ([0-9.]+)"
                            match = re.search(f1_score_pattern, last_line)
                            f1_score = float(match.group(1))
                            f1_list.append(f1_score)
                        except Exception as e:
                            print(e)
                            continue

        elif llm_model in ["equi-vocal"]:
            if task_id != 0:
                for query_class_name in query_class_names:
                    for run_id in range(1):
                        for question_id in question_ids:
                            try:
                                with open(os.path.join(config['log_dir'], "query_execution", "charades", query_class_name, f"num_missing_udfs={task_id}", llm_model, f"qid={question_id}-run={run_id}.log"), "r") as f:
                                    last_line = f.readlines()[-1]
                                f1_score_pattern = r"F1 score: ([0-9.]+)"
                                match = re.search(f1_score_pattern, last_line)
                                f1_score = float(match.group(1))
                                f1_list.append(f1_score)
                            except Exception as e:
                                print(e)
                                continue

        elif llm_model in ['vocal-udf']:
            if task_id != 0:
                for query_class_name in query_class_names:
                    for run_id in range(1):
                        for question_id in question_ids:
                            try:
                                with open(os.path.join(config['log_dir'], "query_execution", "charades", query_class_name, f"num_missing_udfs={task_id}", "ninterp=10-nparams=5-kwargs=True-pixels=False-pretrained_models=False-ntrain_distill=100-selection=both-labels=user-budget=50-llm_method=gpt4v", f"qid={question_id}-run={run_id}.log"), "r") as f:
                                    target_line = f.readlines()[-2]
                                f1_score_pattern = r"F1 score: ([0-9.]+)"
                                match = re.search(f1_score_pattern, target_line)
                                f1_score = 0
                                if match:
                                    f1_score = float(match.group(1))
                                    failed_list.append(0)
                                else:
                                    print(f"failed task: qid={question_id}-run={run_id}")
                                    failed_list.append(1)
                                f1_list.append(f1_score)
                                accuracy_list.append(-1)
                                precision_list.append(-1)
                                recall_list.append(-1)
                            except Exception as e:
                                print(e)
                                continue
        else:
            for run_id in range(5):
                for question_id in question_ids:
                    try:
                        with open(os.path.join(config['output_dir'], "charades", llm_model, f"task_{task}_labels_run_{run_id}_question_{question_id}.json"), "r") as f:
                            data = json.load(f)
                        accuracy_list.append(data["accuracy"])
                        f1_list.append(data["f1"])
                        precision_list.append(data["precision"])
                        recall_list.append(data["recall"])
                        failed_list.append(data["failed"])
                        if '0' in task and data["failed"] > 0:
                            print(run_id, question_id)
                    except Exception as e:
                        print(e)
                        continue


        mean_list.append(np.mean(f1_list))
        std_list.append(np.std(f1_list))
        print(f"task_{task}_mean_accuracy: {np.mean(accuracy_list)}")
        print(f"task_{task}_mean_f1: {np.mean(f1_list)}")
        print(f"task_{task}_mean_precision: {np.mean(precision_list)}")
        print(f"task_{task}_mean_recall: {np.mean(recall_list)}")
        print(f"task_{task}_prob_failures: {np.mean(failed_list)}")
        print()

    offset = width * multiplier
    rects = ax.bar(x + offset, mean_list, width, yerr=std_list, label=llm_model_labels[i], color=CB_color_cycle[i], hatch=hatch_patterns[i])
    # ax.bar_label(rects, padding=3)
    multiplier += 1

# Customize the plot labels and legend
ax.set_title(f"question_ids: {question_ids}")
ax.set(ylabel="F1 Score")
ax.set(xlabel="# new UDFs")
ax.set_ylim(bottom=0, top=1.05)
# ax.set_xlim(left=-1.5)
ax.set_xticks(x + width, num_new_udfs)
# ax.set_xticks(np.arange(len(llm_models) / 2 - 0.5, len(num_new_udfs) * len(llm_models) + len(llm_models) / 2 + 0.5, len(llm_models) + 1))
# ax.set_xticklabels(num_new_udfs)
fig.legend(llm_model_labels, prop={"size": 10}, loc='upper center', bbox_to_anchor=(0.5, 0.07),
           fancybox=True, shadow=False, ncol=2)
# fig.legend(handles_f1, llm_model_labels, prop={"size": 10}, loc='upper center', bbox_to_anchor=(0.5, 0.07),
#            fancybox=True, shadow=False, ncol=2)
plt.subplots_adjust(bottom=0.15)
fig.tight_layout()
plt.show()
# Out:
# ######## gpt-4-1106-preview ########
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_0_question_9.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_1_question_9.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_2_question_9.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_3_question_9.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_1_new_udfs_labels_run_4_question_9.json'
# task_1_new_udfs_mean_accuracy: nan
# task_1_new_udfs_mean_f1: nan
# task_1_new_udfs_mean_precision: nan
# task_1_new_udfs_mean_recall: nan
# task_1_new_udfs_prob_failures: nan
#
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_0_question_9.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_1_question_9.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_2_question_9.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_3_question_9.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_0.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_1.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_2.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_3.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_4.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_5.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_6.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_7.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_8.json'
# [Errno 2] No such file or directory: '/gscratch/balazinska/enhaoz/VOCAL-UDF/outputs/charades/gpt-4-1106-preview/task_2_new_udfs_labels_run_4_question_9.json'
# task_2_new_udfs_mean_accuracy: nan
# task_2_new_udfs_mean_f1: nan
# task_2_new_udfs_mean_precision: nan
# task_2_new_udfs_mean_recall: nan
# task_2_new_udfs_prob_failures: nan
#
# ######## equi-vocal ########
# task_1_new_udfs_mean_accuracy: nan
# task_1_new_udfs_mean_f1: 0.5023030105772178
# task_1_new_udfs_mean_precision: nan
# task_1_new_udfs_mean_recall: nan
# task_1_new_udfs_prob_failures: nan
#
# task_2_new_udfs_mean_accuracy: nan
# task_2_new_udfs_mean_f1: 0.3421525653743756
# task_2_new_udfs_mean_precision: nan
# task_2_new_udfs_mean_recall: nan
# task_2_new_udfs_prob_failures: nan
#
# ######## unavailable_removed ########
# task_1_new_udfs_mean_accuracy: nan
# task_1_new_udfs_mean_f1: 0.5976388628007084
# task_1_new_udfs_mean_precision: nan
# task_1_new_udfs_mean_recall: nan
# task_1_new_udfs_prob_failures: nan
#
# task_2_new_udfs_mean_accuracy: nan
# task_2_new_udfs_mean_f1: 0.45976036300846274
# task_2_new_udfs_mean_precision: nan
# task_2_new_udfs_mean_recall: nan
# task_2_new_udfs_prob_failures: nan
#
# ######## vocal-udf ########
# task_1_new_udfs_mean_accuracy: -1.0
# task_1_new_udfs_mean_f1: 0.6678938379955568
# task_1_new_udfs_mean_precision: -1.0
# task_1_new_udfs_mean_recall: -1.0
# task_1_new_udfs_prob_failures: 0.0
#
# task_2_new_udfs_mean_accuracy: -1.0
# task_2_new_udfs_mean_f1: 0.5265136140825305
# task_2_new_udfs_mean_precision: -1.0
# task_2_new_udfs_mean_recall: -1.0
# task_2_new_udfs_prob_failures: 0.0
# /gscratch/balazinska/enhaoz/jupyter/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /gscratch/balazinska/enhaoz/jupyter/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /gscratch/balazinska/enhaoz/jupyter/lib/python3.11/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /gscratch/balazinska/enhaoz/jupyter/lib/python3.11/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /gscratch/balazinska/enhaoz/jupyter/lib/python3.11/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
# Define LLM models, tasks, number of new UDFs, and hatch patterns
llm_models = ['vocal-udf', 'equi-vocal', 'unavailable_removed', 'gpt-4-1106-preview']
llm_model_labels = ['vocal-udf', 'equi-vocal', 'unavailable_removed', 'visprog']
task_name = "unavailable=2-npred=4-nobj_pred=1-nvars=3-depth=2"
question_ids = list(range(10))
missing_udfs = [1, 2]

tuples = []
for question_id in question_ids:
    for mu in missing_udfs:
        tuples.append((f"Q{question_id}", f"missing={mu}"))
index = pd.MultiIndex.from_tuples(tuples, names=["first", "second"])
df = pd.DataFrame(0.0, index=llm_model_labels, columns=index)

# Iterate through LLM models
for i, llm_model in enumerate(llm_models):
    # Iterate through tasks
    for task_id in missing_udfs:
        # Iterate through runs and questions
        if llm_model in ["unavailable_removed"]:
            if task_id != 0:
                for question_id in question_ids:
                    try:
                        with open(os.path.join(config['log_dir'], "query_execution", "charades", task_name, f"num_missing_udfs={task_id}", "queries_unavailable_udfs_removed", f"qid={question_id}.log"), "r") as f:
                            last_line = f.readlines()[-1]
                        f1_score_pattern = r"F1 score: ([0-9.]+)"
                        match = re.search(f1_score_pattern, last_line)
                        f1_score = float(match.group(1))
                        df.loc[llm_model_labels[i], (f"Q{question_id}", f"missing={task_id}")] = f1_score
                    except Exception as e:
                        print(e)
                        continue

        elif llm_model in ["equi-vocal"]:
            if task_id != 0:
                for question_id in question_ids:
                    f1_list = []
                    for run_id in range(3):
                        try:
                            with open(os.path.join(config['log_dir'], "query_execution", "charades", task_name, f"num_missing_udfs={task_id}", llm_model, f"qid={question_id}-run={run_id}.log"), "r") as f:
                                last_line = f.readlines()[-1]
                            f1_score_pattern = r"F1 score: ([0-9.]+)"
                            match = re.search(f1_score_pattern, last_line)
                            f1_score = float(match.group(1))
                            f1_list.append(f1_score)
                        except Exception as e:
                            print(e)
                            continue
                    df.loc[llm_model_labels[i], (f"Q{question_id}", f"missing={task_id}")] = np.mean(f1_list)

        elif llm_model in ['vocal-udf']:
            if task_id != 0:
                for question_id in question_ids:
                    f1_list = []
                    for run_id in range(3):
                        try:
                            with open(os.path.join(config['log_dir'], "query_execution", "charades", task_name, f"num_missing_udfs={task_id}", "ninterp=10-nparams=5-kwargs=True-pixels=False-pretrained_models=False-ntrain_distill=100-selection=both-labels=user-budget=50-llm_method=gpt4v", f"qid={question_id}-run={run_id}.log"), "r") as f:
                                target_line = f.readlines()[-2]
                            f1_score_pattern = r"F1 score: ([0-9.]+)"
                            match = re.search(f1_score_pattern, target_line)
                            f1_score = float(match.group(1))
                            f1_list.append(f1_score)
                        except Exception as e:
                            print(e)
                            continue
                    df.loc[llm_model_labels[i], (f"Q{question_id}", f"missing={task_id}")] = np.mean(f1_list)
        # else:
        #     for run_id in range(5):
        #         for question_id in question_ids:
        #             try:
        #                 with open(os.path.join(config['output_dir'], "charades", llm_model, f"task_{task}_labels_run_{run_id}_question_{question_id}.json"), "r") as f:
        #                     data = json.load(f)
        #                 accuracy_list.append(data["accuracy"])
        #                 f1_list.append(data["f1"])
        #                 precision_list.append(data["precision"])
        #                 recall_list.append(data["recall"])
        #                 failed_list.append(data["failed"])
        #                 if '0' in task and data["failed"] > 0:
        #                     print(run_id, question_id)
        #             except Exception as e:
        #                 print(e)
        #                 continue

pd.options.display.float_format = '{:.3f}'.format

def highlight_max(s):
    is_max = s == s[:2].max()
    global_is_max = s == s.max()
    res = []
    for i in range(len(is_max)):
        style = ''
        if global_is_max.iloc[i]:
            style += 'font-weight:bold;'
        if is_max.iloc[i]:
            style += 'color: green;'
        res.append(style)
    return res

s = df.style.set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
s.apply(highlight_max).format("{:.3f}")
# Out:
# <style type="text/css">
# #T_9e690 th {
#   text-align: center;
# }
# #T_9e690_row0_col0, #T_9e690_row0_col4, #T_9e690_row0_col5, #T_9e690_row0_col8, #T_9e690_row0_col10, #T_9e690_row0_col11, #T_9e690_row0_col12, #T_9e690_row1_col0 {
#   color: green;
# }
# #T_9e690_row0_col1, #T_9e690_row0_col2, #T_9e690_row0_col6, #T_9e690_row0_col9, #T_9e690_row0_col13, #T_9e690_row0_col14, #T_9e690_row0_col15, #T_9e690_row0_col16, #T_9e690_row0_col17, #T_9e690_row0_col18, #T_9e690_row0_col19, #T_9e690_row1_col3, #T_9e690_row1_col6, #T_9e690_row1_col7 {
#   font-weight: bold;
#   color: green;
# }
# #T_9e690_row2_col0, #T_9e690_row2_col4, #T_9e690_row2_col5, #T_9e690_row2_col8, #T_9e690_row2_col10, #T_9e690_row2_col11, #T_9e690_row2_col12 {
#   font-weight: bold;
# }
# </style>
# <table id="T_9e690">
#   <thead>
#     <tr>
#       <th class="index_name level0" >first</th>
#       <th id="T_9e690_level0_col0" class="col_heading level0 col0" colspan="2">Q0</th>
#       <th id="T_9e690_level0_col2" class="col_heading level0 col2" colspan="2">Q1</th>
#       <th id="T_9e690_level0_col4" class="col_heading level0 col4" colspan="2">Q2</th>
#       <th id="T_9e690_level0_col6" class="col_heading level0 col6" colspan="2">Q3</th>
#       <th id="T_9e690_level0_col8" class="col_heading level0 col8" colspan="2">Q4</th>
#       <th id="T_9e690_level0_col10" class="col_heading level0 col10" colspan="2">Q5</th>
#       <th id="T_9e690_level0_col12" class="col_heading level0 col12" colspan="2">Q6</th>
#       <th id="T_9e690_level0_col14" class="col_heading level0 col14" colspan="2">Q7</th>
#       <th id="T_9e690_level0_col16" class="col_heading level0 col16" colspan="2">Q8</th>
#       <th id="T_9e690_level0_col18" class="col_heading level0 col18" colspan="2">Q9</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >second</th>
#       <th id="T_9e690_level1_col0" class="col_heading level1 col0" >missing=1</th>
#       <th id="T_9e690_level1_col1" class="col_heading level1 col1" >missing=2</th>
#       <th id="T_9e690_level1_col2" class="col_heading level1 col2" >missing=1</th>
#       <th id="T_9e690_level1_col3" class="col_heading level1 col3" >missing=2</th>
#       <th id="T_9e690_level1_col4" class="col_heading level1 col4" >missing=1</th>
#       <th id="T_9e690_level1_col5" class="col_heading level1 col5" >missing=2</th>
#       <th id="T_9e690_level1_col6" class="col_heading level1 col6" >missing=1</th>
#       <th id="T_9e690_level1_col7" class="col_heading level1 col7" >missing=2</th>
#       <th id="T_9e690_level1_col8" class="col_heading level1 col8" >missing=1</th>
#       <th id="T_9e690_level1_col9" class="col_heading level1 col9" >missing=2</th>
#       <th id="T_9e690_level1_col10" class="col_heading level1 col10" >missing=1</th>
#       <th id="T_9e690_level1_col11" class="col_heading level1 col11" >missing=2</th>
#       <th id="T_9e690_level1_col12" class="col_heading level1 col12" >missing=1</th>
#       <th id="T_9e690_level1_col13" class="col_heading level1 col13" >missing=2</th>
#       <th id="T_9e690_level1_col14" class="col_heading level1 col14" >missing=1</th>
#       <th id="T_9e690_level1_col15" class="col_heading level1 col15" >missing=2</th>
#       <th id="T_9e690_level1_col16" class="col_heading level1 col16" >missing=1</th>
#       <th id="T_9e690_level1_col17" class="col_heading level1 col17" >missing=2</th>
#       <th id="T_9e690_level1_col18" class="col_heading level1 col18" >missing=1</th>
#       <th id="T_9e690_level1_col19" class="col_heading level1 col19" >missing=2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e690_level0_row0" class="row_heading level0 row0" >vocal-udf</th>
#       <td id="T_9e690_row0_col0" class="data row0 col0" >0.990</td>
#       <td id="T_9e690_row0_col1" class="data row0 col1" >0.945</td>
#       <td id="T_9e690_row0_col2" class="data row0 col2" >0.270</td>
#       <td id="T_9e690_row0_col3" class="data row0 col3" >0.201</td>
#       <td id="T_9e690_row0_col4" class="data row0 col4" >0.984</td>
#       <td id="T_9e690_row0_col5" class="data row0 col5" >0.983</td>
#       <td id="T_9e690_row0_col6" class="data row0 col6" >1.000</td>
#       <td id="T_9e690_row0_col7" class="data row0 col7" >0.885</td>
#       <td id="T_9e690_row0_col8" class="data row0 col8" >0.865</td>
#       <td id="T_9e690_row0_col9" class="data row0 col9" >0.933</td>
#       <td id="T_9e690_row0_col10" class="data row0 col10" >0.667</td>
#       <td id="T_9e690_row0_col11" class="data row0 col11" >0.730</td>
#       <td id="T_9e690_row0_col12" class="data row0 col12" >0.912</td>
#       <td id="T_9e690_row0_col13" class="data row0 col13" >0.185</td>
#       <td id="T_9e690_row0_col14" class="data row0 col14" >0.840</td>
#       <td id="T_9e690_row0_col15" class="data row0 col15" >0.815</td>
#       <td id="T_9e690_row0_col16" class="data row0 col16" >0.172</td>
#       <td id="T_9e690_row0_col17" class="data row0 col17" >0.192</td>
#       <td id="T_9e690_row0_col18" class="data row0 col18" >0.452</td>
#       <td id="T_9e690_row0_col19" class="data row0 col19" >0.329</td>
#     </tr>
#     <tr>
#       <th id="T_9e690_level0_row1" class="row_heading level0 row1" >equi-vocal</th>
#       <td id="T_9e690_row1_col0" class="data row1 col0" >0.990</td>
#       <td id="T_9e690_row1_col1" class="data row1 col1" >0.773</td>
#       <td id="T_9e690_row1_col2" class="data row1 col2" >0.174</td>
#       <td id="T_9e690_row1_col3" class="data row1 col3" >0.297</td>
#       <td id="T_9e690_row1_col4" class="data row1 col4" >0.901</td>
#       <td id="T_9e690_row1_col5" class="data row1 col5" >0.292</td>
#       <td id="T_9e690_row1_col6" class="data row1 col6" >1.000</td>
#       <td id="T_9e690_row1_col7" class="data row1 col7" >1.000</td>
#       <td id="T_9e690_row1_col8" class="data row1 col8" >0.840</td>
#       <td id="T_9e690_row1_col9" class="data row1 col9" >0.847</td>
#       <td id="T_9e690_row1_col10" class="data row1 col10" >0.398</td>
#       <td id="T_9e690_row1_col11" class="data row1 col11" >0.639</td>
#       <td id="T_9e690_row1_col12" class="data row1 col12" >0.592</td>
#       <td id="T_9e690_row1_col13" class="data row1 col13" >0.182</td>
#       <td id="T_9e690_row1_col14" class="data row1 col14" >0.566</td>
#       <td id="T_9e690_row1_col15" class="data row1 col15" >0.288</td>
#       <td id="T_9e690_row1_col16" class="data row1 col16" >0.155</td>
#       <td id="T_9e690_row1_col17" class="data row1 col17" >0.134</td>
#       <td id="T_9e690_row1_col18" class="data row1 col18" >0.160</td>
#       <td id="T_9e690_row1_col19" class="data row1 col19" >0.094</td>
#     </tr>
#     <tr>
#       <th id="T_9e690_level0_row2" class="row_heading level0 row2" >unavailable_removed</th>
#       <td id="T_9e690_row2_col0" class="data row2 col0" >0.990</td>
#       <td id="T_9e690_row2_col1" class="data row2 col1" >0.897</td>
#       <td id="T_9e690_row2_col2" class="data row2 col2" >0.139</td>
#       <td id="T_9e690_row2_col3" class="data row2 col3" >0.105</td>
#       <td id="T_9e690_row2_col4" class="data row2 col4" >0.992</td>
#       <td id="T_9e690_row2_col5" class="data row2 col5" >0.985</td>
#       <td id="T_9e690_row2_col6" class="data row2 col6" >0.739</td>
#       <td id="T_9e690_row2_col7" class="data row2 col7" >0.620</td>
#       <td id="T_9e690_row2_col8" class="data row2 col8" >0.941</td>
#       <td id="T_9e690_row2_col9" class="data row2 col9" >0.900</td>
#       <td id="T_9e690_row2_col10" class="data row2 col10" >0.801</td>
#       <td id="T_9e690_row2_col11" class="data row2 col11" >0.793</td>
#       <td id="T_9e690_row2_col12" class="data row2 col12" >0.923</td>
#       <td id="T_9e690_row2_col13" class="data row2 col13" >0.176</td>
#       <td id="T_9e690_row2_col14" class="data row2 col14" >0.733</td>
#       <td id="T_9e690_row2_col15" class="data row2 col15" >0.724</td>
#       <td id="T_9e690_row2_col16" class="data row2 col16" >0.144</td>
#       <td id="T_9e690_row2_col17" class="data row2 col17" >0.127</td>
#       <td id="T_9e690_row2_col18" class="data row2 col18" >0.160</td>
#       <td id="T_9e690_row2_col19" class="data row2 col19" >0.140</td>
#     </tr>
#     <tr>
#       <th id="T_9e690_level0_row3" class
