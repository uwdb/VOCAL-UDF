# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create the DataFrame
data = {
    'udf-class': [
        'color-brown', 'color-brown', 'color-brown', 'color-brown', 'color-brown',
        'color-brown', 'color-brown', 'color-brown', 'color-brown', 'color-brown',
        'material-metal', 'material-metal', 'material-metal', 'material-metal', 'material-metal',
        'material-metal', 'material-metal', 'material-metal', 'material-metal', 'material-metal',
        'shape-cylinder', 'shape-cylinder', 'shape-cylinder', 'shape-cylinder', 'shape-cylinder',
        'shape-cylinder', 'shape-cylinder', 'shape-cylinder', 'shape-cylinder', 'shape-cylinder',
        'color-purple', 'color-purple', 'color-purple', 'color-purple', 'color-purple',
        'color-purple', 'color-purple', 'color-purple', 'color-purple', 'color-purple'
    ],
    'method': [
        'code', 'code', 'code', 'code', 'code',
        'model', 'model', 'model', 'model', 'model',
        'code', 'code', 'code', 'code', 'code',
        'model', 'model', 'model', 'model', 'model',
        'code', 'code', 'code', 'code', 'code',
        'model', 'model', 'model', 'model', 'model',
        'code', 'code', 'code', 'code', 'code',
        'model', 'model', 'model', 'model', 'model'
    ],
    'F1 score': [
        0.7840531561, 0.6790123457, 0.9875518672, 0.7083333333, 0.2875816993,
        0.79668051, 0.7179487348, 0.302762419, 0.8974359035, 0.6862745285,
        0.6550100874, 0.6693280106, 0.6763732627, 0.8501362398, 0.670212766,
        0.6075268984, 0.518409431, 0.5663716793, 0.4599708915, 0.6475195885,
        0.5265486726, 0.5260029718, 0.2417218543, 0.4923076923, 0.7288135593,
        0.9434523582, 0.9499284625, 0.9652295113, 0.9656084776, 0.9669064879,
        0.7835051546, 0.9925925926, 0.9306122449, 0.5714285714, 0.1203007519,
        0.8848921061, 0.8654970527, 0.8666666746, 0.8951612711, 0.564971745
    ]
}
df = pd.DataFrame(data)

# Plot the grouped box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='udf-class', y='F1 score', hue='method', data=df)
plt.title('Grouped Box Plot by UDF-Class and Method')
plt.xlabel('UDF-Class')
plt.ylabel('F1 Score')
plt.legend(title='Method')
plt.show()
